# %% [markdown]
# # Optimize Forecast and Thresholding Model

# %%
# !pip install calflops lightning gdown numba pyts==0.12.0
# !pip install --no-deps tsai==0.3.9
# Out:
# Collecting calflops
#   Downloading calflops-0.3.2-py3-none-any.whl.metadata (28 kB)
# Collecting lightning
#   Downloading lightning-2.5.1-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (0.60.0)
# Collecting pyts==0.12.0
#   Downloading pyts-0.12.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.17.5 in /usr/local/lib/python3.10/dist-packages (from pyts==0.12.0) (1.26.4)
# Requirement already satisfied: scipy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pyts==0.12.0) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.22.1 in /usr/local/lib/python3.10/dist-packages (from pyts==0.12.0) (1.2.2)
# Requirement already satisfied: joblib>=0.12 in /usr/local/lib/python3.10/dist-packages (from pyts==0.12.0) (1.4.2)
# Requirement already satisfied: accelerate>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from calflops) (1.2.1)
# Requirement already satisfied: huggingface-hub>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from calflops) (0.29.0)
# Requirement already satisfied: torch>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from calflops) (2.5.1+cu121)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.10/dist-packages (from lightning) (6.0.2)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (2024.12.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from lightning) (0.12.0)
# Requirement already satisfied: packaging<25.0,>=20.0 in /usr/local/lib/python3.10/dist-packages (from lightning) (24.2)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from lightning) (1.6.1)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from lightning) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from lightning) (4.12.2)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.10/dist-packages (from lightning) (2.5.0.post0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.17.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba) (0.43.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.22.0->calflops) (5.9.5)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.22.0->calflops) (0.4.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (3.11.12)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities<2.0,>=0.10.0->lightning) (75.1.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17.5->pyts==0.12.0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17.5->pyts==0.12.0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17.5->pyts==0.12.0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17.5->pyts==0.12.0) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17.5->pyts==0.12.0) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17.5->pyts==0.12.0) (2.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.1->pyts==0.12.0) (3.5.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->calflops) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->calflops) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->calflops) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.1.0->calflops) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2025.1.31)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.1.0->calflops) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.17.5->pyts==0.12.0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.17.5->pyts==0.12.0) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.17.5->pyts==0.12.0) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.17.5->pyts==0.12.0) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.17.5->pyts==0.12.0) (2024.2.0)
# Downloading pyts-0.12.0-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 25.8 MB/s eta 0:00:00
# Downloading calflops-0.3.2-py3-none-any.whl (29 kB)
# Downloading lightning-2.5.1-py3-none-any.whl (818 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 818.9/818.9 kB 40.6 MB/s eta 0:00:00
# Installing collected packages: pyts, lightning, calflops
# Successfully installed calflops-0.3.2 lightning-2.5.1 pyts-0.12.0
# Collecting tsai==0.3.9
#   Downloading tsai-0.3.9-py3-none-any.whl.metadata (16 kB)
# Downloading tsai-0.3.9-py3-none-any.whl (324 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.3/324.3 kB 12.7 MB/s eta 0:00:00
# Installing collected packages: tsai
# Successfully installed tsai-0.3.9

# %%
import os
import yaml
import json
import logging
import warnings
import shutil
import gdown
import optuna
from optuna.samplers import TPESampler
from optuna.exceptions import OptunaError
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from numba import njit
from torch.utils.data import DataLoader, SubsetRandomSampler, Dataset
from calflops import calculate_flops
import lightning as L
from lightning.pytorch.loggers import TensorBoardLogger, Logger
from lightning.pytorch.utilities import disable_possible_user_warnings, rank_zero_only
from fastai.imports import noop
from fastai.layers import AdaptiveConcatPool1d
from tsai.models.layers import Conv, Concat, Norm, ConvBlock, GAP1d, Add
from typing import Literal
from lightning.pytorch.callbacks import EarlyStopping, ModelCheckpoint, LearningRateMonitor


logging.getLogger("lightning.pytorch").setLevel(logging.ERROR)
disable_possible_user_warnings()


class Config:
    """Loads parameters from config.yaml into global object"""
    def __init__(self, path_to_config=None):

        if path_to_config:
            self.path_to_config = path_to_config

            if os.path.isfile(path_to_config):
                pass
            else:
                self.path_to_config = '../{}'.format(self.path_to_config)

            with open(self.path_to_config, "r") as f:
                self.dictionary = yaml.load(f.read(), Loader=yaml.FullLoader)

            for k, v in self.dictionary.items():
                setattr(self, k, v)

    @staticmethod
    def from_dict(d: dict) -> 'Config':
        c = Config()
        c.dictionary = d
        for k, v in c.dictionary.items():
            setattr(c, k, v)
        return c

    def __setitem__(self, key, value):
        self.dictionary[key] = value
        setattr(self, key, value)

    @staticmethod
    def build_group_lookup(path_to_groupings):
        channel_group_lookup = {}

        with open(path_to_groupings, "r") as f:
            groupings = json.loads(f.read())

            for subsystem in groupings.keys():
                for subgroup in groupings[subsystem].keys():
                    for chan in groupings[subsystem][subgroup]:
                        channel_group_lookup[chan["key"]] = {}
                        channel_group_lookup[chan["key"]]["subsystem"] = subsystem
                        channel_group_lookup[chan["key"]]["subgroup"] = subgroup

        return channel_group_lookup


class BaseLightningModel(L.LightningModule):
    def __init__(self, config=None):
        super().__init__()
        self.config = config
        self._val_loss = 0.0
        self._test_loss = 0.0
        self._val_batches = 0
        self._test_batches = 0

    def training_step(self, batch, batch_idx):
        inputs, target = batch
        output = self(inputs)
        loss = self.criterion(output, target)
        self.log("train_loss", loss)
        return loss

    def validation_step(self, batch, batch_idx):
        inputs, target = batch
        output = self(inputs)
        self._val_loss += self.val_criterion(output, target).item()
        self._val_batches += 1

    def test_step(self, batch, batch_idx):
        inputs, target = batch
        output = self(inputs)
        self._test_loss += self.val_criterion(output, target).item()
        self._test_batches += 1

    def predict_step(self, batch, batch_idx, dataloader_idx=0):
        if isinstance(batch, list) or isinstance(batch, tuple):
            batch, y = batch
            return self(batch), y
        return self(batch)

    def configure_optimizers(self):
        if self.config.optimizer == "adam":
            optimizer = torch.optim.Adam(self.parameters(), lr=self.config.lr)
        elif self.config.optimizer == "adamw":
            optimizer = torch.optim.AdamW(self.parameters(), lr=self.config.lr)
        else:
            raise ValueError(f"Unknown optimizer: {self.config.optimizer}")
        if self.config.use_one_cycle:
            scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=self.config.lr, pct_start=0.25,
                                                            total_steps=self.trainer.estimated_stepping_batches)
            opt_config = {
                "optimizer": optimizer,
                "lr_scheduler": {
                    "scheduler": scheduler,
                    "interval": "step",
                    "frequency": 1,
                }
            }
            return opt_config
        return optimizer

    def configure_callbacks(self):
        callbacks = []
        early_stop = EarlyStopping(
            monitor="val_loss",
            patience=self.config.patience,
            min_delta=self.config.min_delta,
            verbose=True
        )
        callbacks.append(early_stop)
        if self.config.modelOutput is not None:
            checkpoint = ModelCheckpoint(
                dirpath=self.config.modelOutput,
                filename="best_{epoch:02d}-{val_loss:.3f}",
                monitor="val_loss",
                save_top_k=1,
                verbose=True,
                save_last=True
            )
            callbacks.append(checkpoint)
        lr_monitor = LearningRateMonitor(logging_interval="step")
        callbacks.append(lr_monitor)
        return callbacks

    def on_validation_epoch_end(self):
        """Compute and log validation metrics at the end of the validation epoch."""
        val_loss = self._val_loss / self._val_batches
        self.log("val_loss", val_loss)
        self._val_loss = 0.0
        self._val_batches = 0

    def on_test_epoch_end(self):
        """Compute and log test metrics at the end of the test epoch."""
        test_loss = self._test_loss / self._test_batches
        self.log("test_loss", test_loss)
        self._test_loss = 0.0
        self._test_batches = 0

    @staticmethod
    def get_act(activation: Literal["relu", "leakyrelu", "mish", "silu", "hardswish", "gelu", "celu", "elu"] = "relu"):
        activation = activation.lower()
        if activation == "relu":
            return torch.nn.ReLU
        elif activation == "leakyrelu":
            return torch.nn.LeakyReLU
        elif activation == "mish":
            return torch.nn.Mish
        elif activation == "silu":  # Swish
            return torch.nn.SiLU
        elif activation == "hardswish":
            return torch.nn.Hardswish
        elif activation == "gelu":
            return torch.nn.GELU
        elif activation == "celu":
            return torch.nn.CELU
        elif activation == "elu":
            return torch.nn.ELU
        else:
            raise ValueError(f"Unknown activation function: {activation}")


class BaseForecaster(BaseLightningModel):
    def __init__(self, config):
        super().__init__(config)
        self.criterion = self.get_loss_metric(self.config.loss_metric)
        self.val_criterion = self.get_loss_metric(self.config.loss_metric)

        self.save_hyperparameters(config.dictionary)

    @staticmethod
    def get_loss_metric(loss_metric: str):
        loss_metric = loss_metric.lower()
        if loss_metric == "mse":
            return torch.nn.MSELoss()
        elif loss_metric == "mae":
            return torch.nn.L1Loss()
        elif loss_metric == "huber":
            return torch.nn.HuberLoss()
        else:
            raise ValueError(f"Unknown loss metric: {loss_metric}")


class XceptionModulePlus(nn.Module):
    def __init__(self, ni, nf, ks=40, kss=None, bottleneck=True, coord=False, separable=True, norm='Batch',
                 bn_1st=True, act=nn.ReLU, act_kwargs=None, norm_act=False):
        super().__init__()
        act_kwargs = {} if act_kwargs is None else act_kwargs
        if kss is None:
            kss = [ks // (2 ** i) for i in range(3)]
        kss = [ksi if ksi % 2 != 0 else ksi - 1 for ksi in kss]  # ensure odd kss for padding='same'
        self.bottleneck = Conv(ni, nf, 1, coord=coord, bias=False) if bottleneck else noop
        self.convs = nn.ModuleList()
        for i in range(len(kss)):
            self.convs.append(Conv(nf if bottleneck else ni, nf, kss[i], coord=coord, separable=separable, bias=False))
        self.mp_conv = nn.Sequential(*[nn.MaxPool1d(3, stride=1, padding=1), Conv(ni, nf, 1, coord=coord, bias=False)])
        self.concat = Concat()
        _norm_act = []
        if act is not None:
            _norm_act.append(act(**act_kwargs))
        _norm_act.append(Norm(nf * 4, norm=norm, zero_norm=False))
        if bn_1st:
            _norm_act.reverse()
        self.norm_act = noop if not norm_act else _norm_act[0] if act is None else nn.Sequential(*_norm_act)

    def forward(self, x):
        input_tensor = x
        x = self.bottleneck(x)
        x = self.concat([l(x) for l in self.convs] + [self.mp_conv(input_tensor)])
        return self.norm_act(x)


class XceptionBlockPlus(nn.Module):
    def __init__(self, ni, nf, residual=True, coord=False, norm='Batch', act=nn.ReLU, act_kwargs=None, dropout=0., **kwargs):
        super().__init__()
        act_kwargs = {} if act_kwargs is None else act_kwargs
        self.residual = residual
        self.xception, self.shortcut, self.act = nn.ModuleList(), nn.ModuleList(), nn.ModuleList()
        for i in range(4):
            if self.residual and (i - 1) % 2 == 0:
                self.shortcut.append(
                    Norm(n_in, norm=norm) if n_in == n_out else
                    ConvBlock(n_in, n_out * 4 * 2, 1, coord=coord, bias=False, norm=norm, act=None, dropout=dropout)
                )
                self.act.append(act(**act_kwargs))
            n_out = nf * 2 ** i
            n_in = ni if i == 0 else n_out * 2
            self.xception.append(XceptionModulePlus(n_in, n_out, coord=coord, norm=norm,
                                                    act=act if self.residual and (i - 1) % 2 == 0 else None, **kwargs))
        self.add = Add()

    def forward(self, x):
        res = x
        for i in range(4):
            x = self.xception[i](x)
            if self.residual and (i + 1) % 2 == 0:
                res = x = self.act[i // 2](self.add(x, self.shortcut[i // 2](res)))
        return x


class XceptionTimePlus(BaseForecaster):
    def __init__(self, config):
        super().__init__(config)

        # params
        c_in = len(config.input_channels)
        c_out = len(config.target_channels) * config.prediction_window_size
        nf = config.nf  # 16
        coord = config.coord  # False
        norm = config.norm  # 'Batch'
        concat_pool = config.concat_pool  # False
        adaptive_size = config.adaptive_size  # 50
        act = self.get_act(config.activation)  # nn.ReLU
        dropout = config.dropout  # 0.
        ks = config.ks  # 40
        bottleneck = config.bottleneck  # True
        bn_1st = config.bn_1st  # True
        norm_act = config.norm_act  # False
        width = config.width  # 16

        self.prediction_window_size = config.prediction_window_size
        self.target_channels = len(config.target_channels)

        # Backbone
        self.backbone = XceptionBlockPlus(c_in, nf, coord=coord, norm=norm, act=act, dropout=dropout, ks=ks,
                                          bottleneck=bottleneck, bn_1st=bn_1st, norm_act=norm_act)
        # Head
        gap1 = AdaptiveConcatPool1d(adaptive_size) if adaptive_size and concat_pool else nn.AdaptiveAvgPool1d(adaptive_size) if adaptive_size else noop
        mult = 2 if adaptive_size and concat_pool else 1
        conv1x1_1 = ConvBlock(nf * 32 * mult, nf * width * mult, 1, coord=coord, norm=norm)
        conv1x1_2 = ConvBlock(nf * width * mult, nf * width // 2 * mult, 1, coord=coord, norm=norm)
        conv1x1_3 = ConvBlock(nf * width // 2 * mult, c_out, 1, coord=coord, norm=norm)
        gap2 = GAP1d(1)
        lin = nn.Linear(c_out, c_out)  # Added by me to avoid ReLU preventing negative values
        self.head = nn.Sequential(gap1, conv1x1_1, conv1x1_2, conv1x1_3, gap2, lin)

    def forward(self, x):
        x = x.permute(0, 2, 1)
        x = self.backbone(x)
        x = self.head(x)
        x = x.view(-1, self.prediction_window_size, self.target_channels)
        return x


class TSForecastDataset(Dataset):
    def __init__(
            self,
            X: np.ndarray,
            window_size: int = 1,
            stride: int = 1,
            pred_horizon: int = 1,
            channels_first: bool = False,
            return_y: bool = True
    ):

        self.window_size = window_size
        self.stride = stride
        self.pred_horizon = pred_horizon
        self.channels_first = channels_first
        self.return_y = return_y
        self.number_of_windows = ((len(X) - window_size - pred_horizon) // stride) + 1
        self.X = torch.tensor(X, dtype=torch.float32)

    def __len__(self):
        return self.number_of_windows

    def __getitem__(self, idx):
        # get window
        start_idx = idx * self.stride
        end_idx = start_idx + self.window_size

        window = self.X[start_idx:end_idx]  # (window_size, n_features)

        # change to channels first format
        if self.channels_first:
            window = window.permute(1, 0)

        # get label and return
        if self.return_y:
            y_end_idx = end_idx + self.pred_horizon
            return window, self.X[end_idx:y_end_idx]
        return window


class InternalLogger(Logger):
    """Internal logger for storing metrics in memory."""
    def __init__(self):
        super().__init__()
        self.metrics = []
        self.hyper_params = {}

    @property
    def history(self):
        """Get metrics history as a DataFrame."""
        metric_df = pd.DataFrame(self.metrics)
        metric_df = metric_df.groupby("step").first().reset_index()
        return metric_df

    @property
    def name(self):
        return "InternalLogger"

    @property
    def version(self):
        return "1.0"

    @rank_zero_only
    def log_hyperparams(self, params):
        self.hyper_params = params

    @rank_zero_only
    def log_metrics(self, metrics, step):
        metrics["step"] = step
        self.metrics.append(metrics)

    @rank_zero_only
    def save(self):
        pass

    @rank_zero_only
    def save_to_csv(self, path: str):
        """Save metrics to a CSV file."""
        metric_df = self.history
        metric_df.to_csv(path)
        print(f"Metrics saved to {path}")

    @rank_zero_only
    def finalize(self, status):
        pass


class TrialError(OptunaError):
    pass


def prepare_forecast_sampler(y: np.ndarray, num_samples: int, window_size: int = 250, stride: int = 1, drop_last: int = 1):
    # Extract labels from the training dataset
    global_labels = y.max(axis=1).astype(int)
    global_labels = global_labels[window_size - 1::stride]
    # Identify indices for nominal windows
    idx_nominal = np.where(global_labels == 0)[0]
    # drop last idx since no future labels exist
    idx_nominal = idx_nominal[:-drop_last]
    # select num_samples randomly
    idx_nominal = np.random.choice(idx_nominal, num_samples, replace=False)
    # Create a sampler for nominal data
    sampler = SubsetRandomSampler(idx_nominal)
    return sampler


@njit
def expand_labels(labels: np.ndarray, forward_extension: int = 1, backward_extension: int = 0) -> np.ndarray:
    """Expands positive labels in a 2D binary label array along the time axis."""
    if labels.ndim != 2:
        raise ValueError("Input array must be 2D with shape (n_samples, n_multi_labels).")

    # Perform label expansion using numba-accelerated function
    n_samples, n_labels = labels.shape
    extended_labels = labels.copy()
    for j in range(n_labels):
        for i in range(n_samples):
            if labels[i, j] == 1:
                start = i - backward_extension
                end = i + forward_extension + 1  # +1 to include the endpoint
                if start < 0:
                    start = 0
                if end > n_samples:
                    end = n_samples
                for k in range(start, end):
                    extended_labels[k, j] = 1

    return extended_labels

# %%
macs_threshold = 70  # Million MACs
params_threshold = 350_000  # Num Params
n_startup_trials = 20
num_samples_per_epoch = 2_097_152  # 2048 steps
num_samples_per_val_epoch = 262_144  # 256 steps
batch_size = 1024
accumulate_grad_batches = 2048 // batch_size  # virtual batch size of 2048
num_evals = 4  # number of evaluations per epoch
split = 264_960
file_dir = "/kaggle/working"
study_name = "model_optimization_ft"
_id = "1-_Ka_AcSqvGPngoVNqcpjovzqhcK6p4O" # Google Drive file id
file_name = "ft_run_04_output.zip"  # zip file to download

seed = 0
stride = 1
in_channels = 6
out_channels = 6
eval_steps = num_samples_per_epoch // batch_size // num_evals
url = f"https://drive.google.com/uc?id={_id}"
output_file = f"{file_dir}/{file_name}"

# %%
# download zip
gdown.download(url, output_file, quiet=False)
# unpack previous run output
shutil.unpack_archive(output_file, file_dir)
# clean up zip file
os.remove(output_file)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-_Ka_AcSqvGPngoVNqcpjovzqhcK6p4O
# To: /kaggle/working/ft_run_04_output.zip
# 100%|██████████| 2.26M/2.26M [00:00<00:00, 180MB/s]

# %%
df_train = pd.read_csv("/kaggle/input/esa-mission-1-train-dataset/84_months.train.csv")
target_channels = [f"channel_{i}" for i in range(41, 47)]
label_cols = ["is_anomaly_" + col for col in target_channels]

train_array = df_train[target_channels].iloc[:-split].values.astype(np.float32)
val_array = df_train[target_channels].iloc[-split:].values.astype(np.float32)
train_labels = df_train[label_cols].iloc[:-split].values.astype(np.float32).clip(0., 1.)
val_labels = df_train[label_cols].iloc[-split:].values.astype(np.float32).clip(0., 1.)

# standard scaling
train_means = np.mean(train_array, axis=0)
train_stds = np.std(train_array, axis=0)
train_array_scaled = (train_array - train_means) / train_stds  # + eps
val_array_scaled = (val_array - train_means) / train_stds  # + eps

train_array_scaled.shape, train_labels.shape, val_array_scaled.shape, val_labels.shape
# Out:
# ((7099201, 6), (7099201, 6), (264960, 6), (264960, 6))

# %%
train_labels = expand_labels(train_labels, 260, 20)  # max lookback 260, max fct horizon 20
val_labels = expand_labels(val_labels, 260, 20)  # max lookback 260, max fct horizon 20

# %%
def objective(trial):
    # sample model configuration
    window_size = trial.suggest_int("window_size", 16, 256, step=8)
    pred_horizon = trial.suggest_int("pred_horizon", 1, 10, step=1)
    nf = trial.suggest_int("nf", 4, 32, step=4)
    coord = trial.suggest_categorical("coord", [True, False])
    norm = trial.suggest_categorical("norm", ["Batch", "Instance"])
    concat_pool = trial.suggest_categorical("concat_pool", [True, False])
    adaptive_size = trial.suggest_int("adaptive_size", 2, 64, step=2)
    activation = trial.suggest_categorical("activation", ["relu", "leakyrelu", "hardswish"])
    dropout = trial.suggest_float("dropout", 0., 0.3, step=0.05)
    ks = trial.suggest_int("ks", 8, 64, step=8)
    bottleneck = trial.suggest_categorical("bottleneck", [True, False])
    bn_1st = trial.suggest_categorical("bn_1st", [True, False])
    norm_act = trial.suggest_categorical("norm_act", [True, False])
    width = trial.suggest_int("width", 4, 16, step=2)

    config = Config.from_dict(
        {
            "input_channels": target_channels,
            "target_channels": target_channels,
            "prediction_window_size": pred_horizon,
            "nf": nf,
            "coord": coord,
            "norm": norm,
            "concat_pool": concat_pool,
            "adaptive_size": adaptive_size,
            "activation": activation,
            "dropout": dropout,
            "ks": ks,
            "bottleneck": bottleneck,
            "bn_1st": bn_1st,
            "norm_act": norm_act,
            "width": width,
            # fixed base params
            "loss_metric": "mse",
            "optimizer": "adam",
            "lr": 2e-4,
            "use_one_cycle": True,
            "patience": 100,
            "min_delta": 0.0,
            "modelOutput": None,
        }
    )

    # set seed
    L.seed_everything(seed=seed, verbose=False)

    # setup datasets
    train_dataset = TSForecastDataset(train_array_scaled, window_size, stride, pred_horizon)
    val_dataset = TSForecastDataset(val_array_scaled, window_size, stride, pred_horizon)

    train_sampler = prepare_forecast_sampler(train_labels, num_samples_per_epoch, window_size, stride, pred_horizon)
    val_sampler = prepare_forecast_sampler(val_labels, num_samples_per_val_epoch, window_size, stride, pred_horizon)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False, drop_last=False, sampler=train_sampler)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, drop_last=False, sampler=val_sampler)

    try:
        # initialize model
        model = XceptionTimePlus(config).cuda()

        # calculate MACs and model parameters
        flops, macs, num_params = calculate_flops(
            model=model,
            input_shape=(1, window_size, in_channels),
            print_results=False,
            output_as_string=False,
            include_backPropagation=False,
        )
        # store all metrics
        trial.set_user_attr("flops", flops)
        trial.set_user_attr("macs", macs)
        trial.set_user_attr("num_params", num_params)

        # scale macs
        macs /= 1_000_000

    except Exception as e:
        raise TrialError(f"Trial {trial.number} model initialization failed: {e}")

    # prune
    # if trial.number >= n_startup_trials:  # Don't prune during startup
    if (macs > macs_threshold) or (num_params > params_threshold):
        raise optuna.TrialPruned()

    # Setup trainer
    metric_logger = InternalLogger()
    # torch.set_float32_matmul_precision("high")

    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        trainer = L.Trainer(
            accelerator="gpu",
            max_epochs=1,
            log_every_n_steps=8,
            accumulate_grad_batches=accumulate_grad_batches,
            logger=[metric_logger, TensorBoardLogger(save_dir=file_dir, name="lightning_logs")],
            val_check_interval=eval_steps,
            enable_model_summary=False,
            enable_progress_bar=False,
            enable_checkpointing=False,
        )

    try:
        # train model
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            trainer.fit(model, train_dataloaders=train_loader, val_dataloaders=val_loader)

        # get min validation loss
        metric_df = metric_logger.history
        loss = metric_df["val_loss"].min()
        trial.set_user_attr("val_loss", loss)

    except Exception as e:
        raise TrialError(f"Trial {trial.number} training failed: {e}")

    if (loss is None) or (np.isnan(loss)):
        raise TrialError("No validation loss")
    if (macs is None) or (np.isnan(macs)):
        raise TrialError("No MACs")

    return macs, loss

# %%
sampler = TPESampler(n_startup_trials=n_startup_trials, multivariate=True, seed=seed)
study = optuna.create_study(
    storage=f"sqlite:///{file_dir}/{study_name}.db",
    study_name=study_name,
    sampler=sampler,
    directions=["minimize", "minimize"],
    load_if_exists=True,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/optuna/_experimental.py:31: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2025-03-26 11:42:15,848] Using an existing study with name 'model_optimization_ft' instead of creating a new one.

# %%
study.optimize(
    objective,
    n_trials=75,
    timeout=int(60 * 60 * 5),
    catch=(TrialError,),
    gc_after_trial=True
)
# Out:
# [I 2025-03-26 11:43:46,117] Trial 37 finished with values: [0.484544, 0.025798408314585686] and parameters: {'window_size': 16, 'pred_horizon': 4, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 4, 'activation': 'hardswish', 'dropout': 0.05, 'ks': 48, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 8}.
# [I 2025-03-26 11:45:46,681] Trial 38 finished with values: [2.361672, 0.025406941771507263] and parameters: {'window_size': 24, 'pred_horizon': 2, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 6, 'activation': 'hardswish', 'dropout': 0.05, 'ks': 48, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 8}.
# [I 2025-03-26 11:47:03,108] Trial 39 finished with values: [0.343144, 0.026380909606814384] and parameters: {'window_size': 16, 'pred_horizon': 3, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 2, 'activation': 'hardswish', 'dropout': 0.05, 'ks': 24, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 11:49:46,188] Trial 40 finished with values: [4.802256, 0.026518847793340683] and parameters: {'window_size': 64, 'pred_horizon': 3, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 6, 'activation': 'hardswish', 'dropout': 0.1, 'ks': 24, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 6}.
# [I 2025-03-26 11:53:09,531] Trial 41 finished with values: [6.611952, 0.026394976302981377] and parameters: {'window_size': 72, 'pred_horizon': 4, 'nf': 8, 'coord': False, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 8, 'activation': 'hardswish', 'dropout': 0.05, 'ks': 48, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 12}.
# [I 2025-03-26 11:55:20,438] Trial 42 finished with values: [1.991544, 0.027061309665441513] and parameters: {'window_size': 72, 'pred_horizon': 3, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': False, 'adaptive_size': 6, 'activation': 'relu', 'dropout': 0.05, 'ks': 56, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 10}.
# [I 2025-03-26 11:59:02,699] Trial 43 finished with values: [2.899728, 0.12442399561405182] and parameters: {'window_size': 32, 'pred_horizon': 4, 'nf': 8, 'coord': True, 'norm': 'Instance', 'concat_pool': True, 'adaptive_size': 6, 'activation': 'hardswish', 'dropout': 0.0, 'ks': 40, 'bottleneck': False, 'bn_1st': False, 'norm_act': False, 'width': 8}.
# [I 2025-03-26 12:01:01,469] Trial 44 finished with values: [1.682924, 0.027521025389432907] and parameters: {'window_size': 64, 'pred_horizon': 3, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 4, 'activation': 'hardswish', 'dropout': 0.1, 'ks': 48, 'bottleneck': False, 'bn_1st': True, 'norm_act': True, 'width': 6}.
# [I 2025-03-26 12:04:34,338] Trial 45 finished with values: [5.181528, 0.027488991618156433] and parameters: {'window_size': 48, 'pred_horizon': 1, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 14, 'activation': 'hardswish', 'dropout': 0.05, 'ks': 64, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 8}.
# [I 2025-03-26 12:05:39,425] Trial 46 finished with values: [0.465412, 0.027571525424718857] and parameters: {'window_size': 16, 'pred_horizon': 1, 'nf': 4, 'coord': False, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 20, 'activation': 'leakyrelu', 'dropout': 0.0, 'ks': 16, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 12:07:33,263] Trial 47 finished with values: [2.87448, 0.02582716941833496] and parameters: {'window_size': 32, 'pred_horizon': 2, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 24, 'activation': 'leakyrelu', 'dropout': 0.0, 'ks': 8, 'bottleneck': False, 'bn_1st': False, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 12:09:23,861] Trial 48 finished with values: [2.591964, 0.025771290063858032] and parameters: {'window_size': 32, 'pred_horizon': 3, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 12, 'activation': 'leakyrelu', 'dropout': 0.05, 'ks': 24, 'bottleneck': True, 'bn_1st': True, 'norm_act': False, 'width': 6}.
# [I 2025-03-26 12:10:41,657] Trial 49 finished with values: [0.691632, 0.02584579959511757] and parameters: {'window_size': 24, 'pred_horizon': 4, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 4, 'activation': 'hardswish', 'dropout': 0.1, 'ks': 40, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 12}.
# [I 2025-03-26 12:11:59,295] Trial 50 finished with values: [0.52628, 0.02591041289269924] and parameters: {'window_size': 16, 'pred_horizon': 6, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 6, 'activation': 'hardswish', 'dropout': 0.05, 'ks': 48, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 8}.
# [I 2025-03-26 12:14:44,605] Trial 51 finished with values: [4.063824, 0.02610042504966259] and parameters: {'window_size': 56, 'pred_horizon': 6, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 8, 'activation': 'hardswish', 'dropout': 0.0, 'ks': 56, 'bottleneck': True, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 12:17:03,074] Trial 52 finished with values: [1.116156, 0.15563680231571198] and parameters: {'window_size': 40, 'pred_horizon': 1, 'nf': 4, 'coord': True, 'norm': 'Instance', 'concat_pool': True, 'adaptive_size': 20, 'activation': 'hardswish', 'dropout': 0.05, 'ks': 40, 'bottleneck': True, 'bn_1st': True, 'norm_act': False, 'width': 8}.
# [I 2025-03-26 12:19:41,475] Trial 53 finished with values: [1.507804, 0.09587406367063522] and parameters: {'window_size': 40, 'pred_horizon': 3, 'nf': 4, 'coord': True, 'norm': 'Instance', 'concat_pool': True, 'adaptive_size': 20, 'activation': 'leakyrelu', 'dropout': 0.0, 'ks': 48, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 10}.
# [I 2025-03-26 12:21:18,607] Trial 54 finished with values: [1.468032, 0.02745528519153595] and parameters: {'window_size': 64, 'pred_horizon': 4, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': False, 'adaptive_size': 16, 'activation': 'hardswish', 'dropout': 0.0, 'ks': 32, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 6}.
# [I 2025-03-26 12:23:05,367] Trial 55 finished with values: [1.917996, 0.02550496533513069] and parameters: {'window_size': 24, 'pred_horizon': 3, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 4, 'activation': 'relu', 'dropout': 0.1, 'ks': 56, 'bottleneck': True, 'bn_1st': True, 'norm_act': False, 'width': 8}.
# [I 2025-03-26 12:25:12,172] Trial 56 finished with values: [4.190976, 0.02514471858739853] and parameters: {'window_size': 16, 'pred_horizon': 4, 'nf': 12, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 16, 'activation': 'relu', 'dropout': 0.25, 'ks': 48, 'bottleneck': True, 'bn_1st': True, 'norm_act': False, 'width': 6}.
# [I 2025-03-26 12:29:07,605] Trial 57 finished with values: [6.305636, 0.02599053457379341] and parameters: {'window_size': 40, 'pred_horizon': 3, 'nf': 12, 'coord': True, 'norm': 'Batch', 'concat_pool': False, 'adaptive_size': 32, 'activation': 'relu', 'dropout': 0.15000000000000002, 'ks': 56, 'bottleneck': True, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 12:31:32,622] Trial 58 finished with values: [3.8409, 0.025961875915527344] and parameters: {'window_size': 40, 'pred_horizon': 5, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 16, 'activation': 'relu', 'dropout': 0.25, 'ks': 48, 'bottleneck': True, 'bn_1st': True, 'norm_act': False, 'width': 8}.
# [I 2025-03-26 12:33:23,152] Trial 59 finished with values: [1.866384, 0.025387119501829147] and parameters: {'window_size': 16, 'pred_horizon': 4, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 18, 'activation': 'hardswish', 'dropout': 0.05, 'ks': 40, 'bottleneck': False, 'bn_1st': False, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 12:35:14,995] Trial 60 finished with values: [1.669136, 0.027576826512813568] and parameters: {'window_size': 80, 'pred_horizon': 5, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 18, 'activation': 'hardswish', 'dropout': 0.1, 'ks': 32, 'bottleneck': True, 'bn_1st': False, 'norm_act': False, 'width': 6}.
# [I 2025-03-26 12:41:29,642] Trial 61 finished with values: [14.919664, 0.026484094560146332] and parameters: {'window_size': 80, 'pred_horizon': 4, 'nf': 12, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 18, 'activation': 'relu', 'dropout': 0.1, 'ks': 56, 'bottleneck': False, 'bn_1st': False, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 12:46:34,091] Trial 62 finished with values: [10.283712, 0.025980904698371887] and parameters: {'window_size': 48, 'pred_horizon': 6, 'nf': 12, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 36, 'activation': 'hardswish', 'dropout': 0.05, 'ks': 32, 'bottleneck': False, 'bn_1st': False, 'norm_act': True, 'width': 4}.
# [I 2025-03-26 12:49:49,518] Trial 63 finished with values: [4.995632, 0.026239993050694466] and parameters: {'window_size': 56, 'pred_horizon': 4, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 20, 'activation': 'hardswish', 'dropout': 0.05, 'ks': 40, 'bottleneck': False, 'bn_1st': False, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 12:51:07,184] Trial 64 finished with values: [0.576536, 0.027950823307037354] and parameters: {'window_size': 16, 'pred_horizon': 2, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 22, 'activation': 'leakyrelu', 'dropout': 0.05, 'ks': 40, 'bottleneck': False, 'bn_1st': False, 'norm_act': True, 'width': 4}.
# [I 2025-03-26 12:53:09,426] Trial 65 finished with values: [1.000704, 0.15778405964374542] and parameters: {'window_size': 56, 'pred_horizon': 4, 'nf': 4, 'coord': True, 'norm': 'Instance', 'concat_pool': True, 'adaptive_size': 6, 'activation': 'relu', 'dropout': 0.15000000000000002, 'ks': 8, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 12:54:55,216] Trial 66 finished with values: [3.410928, 0.025757042691111565] and parameters: {'window_size': 16, 'pred_horizon': 6, 'nf': 12, 'coord': False, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 14, 'activation': 'hardswish', 'dropout': 0.0, 'ks': 16, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 12:57:04,596] Trial 67 finished with values: [3.826188, 0.02577950991690159] and parameters: {'window_size': 24, 'pred_horizon': 7, 'nf': 12, 'coord': True, 'norm': 'Batch', 'concat_pool': False, 'adaptive_size': 4, 'activation': 'hardswish', 'dropout': 0.1, 'ks': 32, 'bottleneck': False, 'bn_1st': False, 'norm_act': False, 'width': 6}.
# [I 2025-03-26 13:00:35,733] Trial 68 finished with values: [1.230816, 0.114545539021492] and parameters: {'window_size': 16, 'pred_horizon': 4, 'nf': 8, 'coord': False, 'norm': 'Instance', 'concat_pool': False, 'adaptive_size': 14, 'activation': 'hardswish', 'dropout': 0.1, 'ks': 24, 'bottleneck': False, 'bn_1st': True, 'norm_act': True, 'width': 4}.
# [I 2025-03-26 13:01:47,573] Trial 69 finished with values: [0.773584, 0.027660537511110306] and parameters: {'window_size': 32, 'pred_horizon': 2, 'nf': 4, 'coord': False, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 10, 'activation': 'hardswish', 'dropout': 0.05, 'ks': 32, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 13:03:10,656] Trial 70 finished with values: [0.684272, 0.028574323281645775] and parameters: {'window_size': 40, 'pred_horizon': 2, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': False, 'adaptive_size': 4, 'activation': 'hardswish', 'dropout': 0.05, 'ks': 24, 'bottleneck': True, 'bn_1st': False, 'norm_act': True, 'width': 6}.
# [I 2025-03-26 13:05:28,807] Trial 71 finished with values: [3.02056, 0.025214780122041702] and parameters: {'window_size': 16, 'pred_horizon': 4, 'nf': 12, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 6, 'activation': 'hardswish', 'dropout': 0.05, 'ks': 40, 'bottleneck': False, 'bn_1st': False, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 13:07:07,995] Trial 72 finished with values: [1.010668, 0.027546066790819168] and parameters: {'window_size': 48, 'pred_horizon': 3, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 4, 'activation': 'hardswish', 'dropout': 0.1, 'ks': 24, 'bottleneck': False, 'bn_1st': False, 'norm_act': True, 'width': 4}.
# [I 2025-03-26 13:08:44,262] Trial 73 finished with values: [0.898976, 0.027560612186789513] and parameters: {'window_size': 40, 'pred_horizon': 4, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 2, 'activation': 'hardswish', 'dropout': 0.0, 'ks': 32, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 13:11:47,006] Trial 74 finished with values: [3.586576, 0.026016613468527794] and parameters: {'window_size': 40, 'pred_horizon': 8, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 4, 'activation': 'hardswish', 'dropout': 0.0, 'ks': 48, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 10}.
# [I 2025-03-26 13:13:28,325] Trial 75 finished with values: [1.61276, 0.025403879582881927] and parameters: {'window_size': 16, 'pred_horizon': 2, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 14, 'activation': 'hardswish', 'dropout': 0.0, 'ks': 24, 'bottleneck': False, 'bn_1st': True, 'norm_act': True, 'width': 4}.
# [I 2025-03-26 13:15:29,321] Trial 76 finished with values: [3.732904, 0.025268996134400368] and parameters: {'window_size': 16, 'pred_horizon': 2, 'nf': 12, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 18, 'activation': 'hardswish', 'dropout': 0.0, 'ks': 16, 'bottleneck': False, 'bn_1st': True, 'norm_act': True, 'width': 4}.
# [I 2025-03-26 13:15:31,167] Trial 77 pruned.
# [I 2025-03-26 13:17:04,754] Trial 78 finished with values: [0.306016, 0.16653546690940857] and parameters: {'window_size': 16, 'pred_horizon': 2, 'nf': 4, 'coord': True, 'norm': 'Instance', 'concat_pool': True, 'adaptive_size': 4, 'activation': 'hardswish', 'dropout': 0.15000000000000002, 'ks': 8, 'bottleneck': False, 'bn_1st': False, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 13:18:21,282] Trial 79 finished with values: [0.598584, 0.027001015841960907] and parameters: {'window_size': 24, 'pred_horizon': 2, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 14, 'activation': 'hardswish', 'dropout': 0.15000000000000002, 'ks': 8, 'bottleneck': False, 'bn_1st': False, 'norm_act': False, 'width': 6}.
# [I 2025-03-26 13:19:37,518] Trial 80 finished with values: [0.5016, 0.02640826627612114] and parameters: {'window_size': 24, 'pred_horizon': 4, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 6, 'activation': 'relu', 'dropout': 0.0, 'ks': 16, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 13:19:39,333] Trial 81 pruned.
# [I 2025-03-26 13:21:22,387] Trial 82 finished with values: [0.479168, 0.13153523206710815] and parameters: {'window_size': 16, 'pred_horizon': 3, 'nf': 4, 'coord': True, 'norm': 'Instance', 'concat_pool': True, 'adaptive_size': 14, 'activation': 'hardswish', 'dropout': 0.05, 'ks': 32, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 13:22:58,633] Trial 83 finished with values: [1.547328, 0.02538200654089451] and parameters: {'window_size': 16, 'pred_horizon': 4, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 12, 'activation': 'leakyrelu', 'dropout': 0.05, 'ks': 24, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 13:24:16,325] Trial 84 finished with values: [0.581776, 0.03113529458642006] and parameters: {'window_size': 24, 'pred_horizon': 4, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': False, 'adaptive_size': 22, 'activation': 'relu', 'dropout': 0.15000000000000002, 'ks': 32, 'bottleneck': False, 'bn_1st': True, 'norm_act': True, 'width': 4}.
# [I 2025-03-26 13:25:35,013] Trial 85 finished with values: [0.31886, 0.027813702821731567] and parameters: {'window_size': 16, 'pred_horizon': 3, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 4, 'activation': 'hardswish', 'dropout': 0.1, 'ks': 32, 'bottleneck': True, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 13:27:11,482] Trial 86 finished with values: [1.435464, 0.030677977949380875] and parameters: {'window_size': 80, 'pred_horizon': 3, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': False, 'adaptive_size': 10, 'activation': 'hardswish', 'dropout': 0.15000000000000002, 'ks': 32, 'bottleneck': True, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 13:28:31,414] Trial 87 finished with values: [0.498452, 0.02657145820558071] and parameters: {'window_size': 24, 'pred_horizon': 5, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 8, 'activation': 'hardswish', 'dropout': 0.15000000000000002, 'ks': 32, 'bottleneck': True, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 13:28:33,217] Trial 88 pruned.
# [I 2025-03-26 13:30:59,337] Trial 89 finished with values: [1.528404, 0.08733578771352768] and parameters: {'window_size': 72, 'pred_horizon': 5, 'nf': 4, 'coord': True, 'norm': 'Instance', 'concat_pool': True, 'adaptive_size': 16, 'activation': 'hardswish', 'dropout': 0.3, 'ks': 8, 'bottleneck': False, 'bn_1st': False, 'norm_act': False, 'width': 8}.
# [I 2025-03-26 13:33:26,641] Trial 90 finished with values: [4.640112, 0.026490909978747368] and parameters: {'window_size': 64, 'pred_horizon': 4, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 14, 'activation': 'hardswish', 'dropout': 0.05, 'ks': 24, 'bottleneck': True, 'bn_1st': True, 'norm_act': True, 'width': 6}.
# [I 2025-03-26 13:35:14,270] Trial 91 finished with values: [2.457488, 0.02552775666117668] and parameters: {'window_size': 32, 'pred_horizon': 3, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 6, 'activation': 'hardswish', 'dropout': 0.1, 'ks': 16, 'bottleneck': True, 'bn_1st': True, 'norm_act': False, 'width': 10}.
# [I 2025-03-26 13:36:50,029] Trial 92 finished with values: [1.29684, 0.026080315932631493] and parameters: {'window_size': 32, 'pred_horizon': 6, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 30, 'activation': 'leakyrelu', 'dropout': 0.05, 'ks': 32, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 8}.
# [I 2025-03-26 13:40:00,250] Trial 93 finished with values: [3.866484, 0.1738065481185913] and parameters: {'window_size': 56, 'pred_horizon': 1, 'nf': 8, 'coord': False, 'norm': 'Instance', 'concat_pool': False, 'adaptive_size': 10, 'activation': 'hardswish', 'dropout': 0.1, 'ks': 16, 'bottleneck': False, 'bn_1st': False, 'norm_act': False, 'width': 8}.
# [I 2025-03-26 13:41:15,595] Trial 94 finished with values: [0.353848, 0.026054270565509796] and parameters: {'window_size': 16, 'pred_horizon': 5, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 6, 'activation': 'leakyrelu', 'dropout': 0.1, 'ks': 16, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 13:42:45,163] Trial 95 finished with values: [1.147272, 0.027719151228666306] and parameters: {'window_size': 64, 'pred_horizon': 2, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 2, 'activation': 'hardswish', 'dropout': 0.15000000000000002, 'ks': 32, 'bottleneck': True, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 13:47:17,048] Trial 96 finished with values: [5.347232, 0.09629516303539276] and parameters: {'window_size': 32, 'pred_horizon': 4, 'nf': 12, 'coord': True, 'norm': 'Instance', 'concat_pool': True, 'adaptive_size': 10, 'activation': 'hardswish', 'dropout': 0.1, 'ks': 16, 'bottleneck': True, 'bn_1st': False, 'norm_act': False, 'width': 6}.
# [I 2025-03-26 13:49:56,951] Trial 97 finished with values: [3.786636, 0.026294583454728127] and parameters: {'window_size': 48, 'pred_horizon': 5, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 12, 'activation': 'leakyrelu', 'dropout': 0.1, 'ks': 24, 'bottleneck': False, 'bn_1st': True, 'norm_act': True, 'width': 4}.
# [I 2025-03-26 13:49:58,753] Trial 98 pruned.
# [I 2025-03-26 13:51:47,913] Trial 99 finished with values: [2.060016, 0.02864529937505722] and parameters: {'window_size': 32, 'pred_horizon': 1, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 2, 'activation': 'relu', 'dropout': 0.05, 'ks': 32, 'bottleneck': True, 'bn_1st': False, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 13:54:41,881] Trial 100 finished with values: [4.729536, 0.03974637761712074] and parameters: {'window_size': 56, 'pred_horizon': 1, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 18, 'activation': 'leakyrelu', 'dropout': 0.2, 'ks': 32, 'bottleneck': False, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 13:56:03,466] Trial 101 finished with values: [0.982888, 0.02553701587021351] and parameters: {'window_size': 16, 'pred_horizon': 3, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 2, 'activation': 'hardswish', 'dropout': 0.1, 'ks': 8, 'bottleneck': True, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 13:57:23,830] Trial 102 finished with values: [0.805812, 0.04118980094790459] and parameters: {'window_size': 32, 'pred_horizon': 1, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 24, 'activation': 'hardswish', 'dropout': 0.05, 'ks': 40, 'bottleneck': True, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 13:57:25,656] Trial 103 pruned.
# [I 2025-03-26 13:58:47,907] Trial 104 finished with values: [1.110496, 0.025537963956594467] and parameters: {'window_size': 16, 'pred_horizon': 4, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 4, 'activation': 'hardswish', 'dropout': 0.05, 'ks': 24, 'bottleneck': True, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 14:00:16,789] Trial 105 finished with values: [0.455652, 0.14378584921360016] and parameters: {'window_size': 24, 'pred_horizon': 3, 'nf': 4, 'coord': False, 'norm': 'Instance', 'concat_pool': False, 'adaptive_size': 12, 'activation': 'hardswish', 'dropout': 0.15000000000000002, 'ks': 40, 'bottleneck': True, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 14:00:18,623] Trial 106 pruned.
# [I 2025-03-26 14:01:42,862] Trial 107 finished with values: [1.476624, 0.025391070172190666] and parameters: {'window_size': 16, 'pred_horizon': 2, 'nf': 8, 'coord': True, 'norm': 'Batch', 'concat_pool': True, 'adaptive_size': 16, 'activation': 'hardswish', 'dropout': 0.15000000000000002, 'ks': 8, 'bottleneck': True, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 14:01:44,652] Trial 108 pruned.
# [I 2025-03-26 14:04:43,296] Trial 109 finished with values: [2.561488, 0.14405936002731323] and parameters: {'window_size': 40, 'pred_horizon': 2, 'nf': 8, 'coord': True, 'norm': 'Instance', 'concat_pool': True, 'adaptive_size': 8, 'activation': 'hardswish', 'dropout': 0.05, 'ks': 8, 'bottleneck': True, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 14:06:00,958] Trial 110 finished with values: [0.437016, 0.028953036293387413] and parameters: {'window_size': 24, 'pred_horizon': 1, 'nf': 4, 'coord': True, 'norm': 'Batch', 'concat_pool': False, 'adaptive_size': 6, 'activation': 'leakyrelu', 'dropout': 0.05, 'ks': 32, 'bottleneck': True, 'bn_1st': True, 'norm_act': False, 'width': 4}.
# [I 2025-03-26 14:07:46,002] Trial 111 finished with values: [0.373216, 0.17560268938541412] and parameters: {'window_size': 16, 'pred_horizon': 2, 'nf': 4, 'coord': True, 'norm': 'Instance', 'concat_pool': True, 'adaptive_size': 4, 'activation': 'hardswish', 'dropout': 0.15000000000000002, 'ks': 16, 'bottleneck': False, 'bn_1st': False, 'norm_act': False, 'width': 8}.
